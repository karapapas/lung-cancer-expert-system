# %%
# !python --version
# use python 3.8.17
# Out:
# Python 3.8.17

# %%
# !pip install experta
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: experta in c:\programdata\anaconda3\envs\dss-env-01\lib\site-packages (1.9.4)
# Requirement already satisfied: frozendict==1.2 in c:\programdata\anaconda3\envs\dss-env-01\lib\site-packages (from experta) (1.2)
# Requirement already satisfied: schema==0.6.7 in c:\programdata\anaconda3\envs\dss-env-01\lib\site-packages (from experta) (0.6.7)

# %%
from experta import *
from rules import *
import numpy as np

# %%
# Initialize the knowledge engines.
suspicion_engine = SuspicionInvestigation()
tumor_engine = TumorStage()
nodes_engine = NodesStage()
metastasis_engine = MetastasisStage()
cancer_engine = CancerStage()

# %%
from utilities import Utils
from logistics import Costs
import re

c = Costs()
u = Utils()

# we consider suspicion, tumor, nodes, metastasis and cancer stages ready to be determined 
# if no relevant requirement is missing (None)
def ready_to_determine(my_dict):
    for value in my_dict.values():
        if value is None:
            return False
    return True

def determine(engine, fact, data):
    engine.reset()
    engine.declare(fact(**data))
    engine.run()
    return engine.get_result()

def exam_for_tumor(subject):
    print(subject.tumor_requirements)
    for attr_name, attr_value in subject.tumor_requirements.items():
        if attr_name == 'mass' and attr_value is None:
            subject.tumor_requirements['mass'] = random.choice([True, False])
            extra_cost = u.gaussian(c.pricelist["x_rays"][0], c.pricelist["x_rays"][1])
            extra_delay = u.gaussian(c.delay["x_rays"][0], c.delay["x_rays"][1])
            print('extra cost for chest x_rays: ', round(extra_cost, 2))
            print('extra delay for chest x_rays: ', int(extra_delay))
            subject.total_cost += round(extra_cost, 2) 
            subject.total_delay += int(extra_delay) 
            return
        
        if attr_name == 'diameter' and attr_value is None:
            if subject.tumor_requirements['mass'] and subject.tumor_requirements['mass'] == True:
                subject.tumor_requirements['diameter'] = round(random.uniform(0, 14), 2)
                rand = round(random.uniform(0, 10), 2)
                if rand <= 2:
                    subject.tumor_requirements['nearby_organs'] = True
                    subject.tumor_requirements['fna_and_pet_scan'] = True
                else:
                    subject.tumor_requirements['nearby_organs'] = False
                    subject.tumor_requirements['fna_and_pet_scan'] = True                    
            else:
                subject.tumor_requirements['diameter'] = 0.0
                subject.tumor_requirements['nearby_organs'] = False
                subject.tumor_requirements['fna_and_pet_scan'] = False
            extra_cost = u.gaussian(c.pricelist["ct_scan"][0], c.pricelist["ct_scan"][1])
            extra_delay = u.gaussian(c.delay["ct_scan"][0], c.delay["ct_scan"][1])
            print('extra cost for ct_scan: ', round(extra_cost, 2))
            print('extra delay for ct_scan: ', int(extra_delay))
            subject.total_cost += round(extra_cost, 2) 
            subject.total_delay += int(extra_delay)
            return
                
        if attr_name == 'bronchoscopesis' and attr_value is None:
            subject.tumor_requirements['bronchoscopesis'] = random.choice([True, False])
            extra_cost = u.gaussian(c.pricelist["bronchoscopesis"][0], c.pricelist["bronchoscopesis"][1])
            extra_delay = u.gaussian(c.delay["bronchoscopesis"][0], c.delay["bronchoscopesis"][1])
            print('extra cost for bronchoscopesis: ', round(extra_cost, 2))
            print('extra delay for bronchoscopesis: ', int(extra_delay))
            subject.total_cost += round(extra_cost, 2)
            subject.total_delay += int(extra_delay)
            return
        
        if attr_name == 'cytologic' and attr_value is None:
            subject.tumor_requirements['cytologic'] = random.choice([True, False])
            extra_cost = u.gaussian(c.pricelist["cytologic"][0], c.pricelist["cytologic"][1])
            extra_delay = u.gaussian(c.delay["cytologic"][0], c.delay["cytologic"][1])
            print('extra cost for cytologic: ', round(extra_cost, 2))
            print('extra delay for cytologic: ', int(extra_delay))
            subject.total_cost += round(extra_cost, 2) 
            subject.total_delay += int(extra_delay)
            return
        
        if attr_name == 'fna_and_pet_scan' and attr_value is None:
            subject.tumor_requirements['fna_and_pet_scan'] = random.choice([True, False])
            extra_cost = u.gaussian(c.pricelist["fna_and_pet_scan"][0], c.pricelist["fna_and_pet_scan"][1])
            extra_delay = u.gaussian(c.delay["fna_and_pet_scan"][0], c.delay["fna_and_pet_scan"][1])
            print('extra cost for fna_and_pet_scan: ', round(extra_cost, 2))
            print('extra delay for fna_and_pet_scan: ', int(extra_delay))
            subject.total_cost += round(extra_cost, 2) 
            subject.total_delay += int(extra_delay)
            return
            
def exam_for_nodes(subject):
    for attr_name, attr_value in subject.nodes_requirements.items():
        if attr_name == 'lymph_nodes_size' and attr_value is None:
            if subject.tumor_stage == 'T0':
                subject.nodes_requirements['lymph_nodes_size'] = 0.5
                subject.nodes_requirements['peribronchial_metastasis'] = False
                subject.nodes_requirements['mediastinal_metastasis'] = False
            elif re.match('T1.', subject.tumor_stage):
                subject.nodes_requirements['lymph_nodes_size'] = round(random.uniform(0.5, 1.5), 2)
                subject.nodes_requirements['peribronchial_metastasis'] = False
                subject.nodes_requirements['mediastinal_metastasis'] = False
            else:
                subject.nodes_requirements['lymph_nodes_size'] = round(random.uniform(1.6, 11), 2)
                subject.nodes_requirements['peribronchial_metastasis'] = random.choice([True, False])
                subject.nodes_requirements['mediastinal_metastasis'] = True

            extra_cost = u.gaussian(c.pricelist["ct_scan"][0], c.pricelist["ct_scan"][1])
            extra_delay = u.gaussian(c.delay["ct_scan"][0], c.delay["ct_scan"][1])
            print('extra cost for ct_scan: ', round(extra_cost, 2))
            print('extra delay for ct_scan: ', int(extra_delay))
            subject.total_cost += round(extra_cost, 2) 
            subject.total_delay += int(extra_delay) 
            return
        
        if attr_name == 'peribronchial_metastasis' and attr_value is None:
            subject.nodes_requirements['peribronchial_metastasis'] = random.choice([True, False])
            subject.nodes_requirements['mediastinal_metastasis'] = random.choice([True, False])
            extra_cost = u.gaussian(c.pricelist["pet_scan"][0], c.pricelist["pet_scan"][1])
            extra_delay = u.gaussian(c.delay["pet_scan"][0], c.delay["pet_scan"][1])
            print('extra cost for pet_scan: ', round(extra_cost, 2))
            print('extra delay for pet_scan: ', int(extra_delay))
            subject.total_cost += round(extra_cost, 2) 
            subject.total_delay += int(extra_delay) 
            return
        
        if attr_name == 'fna_positive' and attr_value is None:
            subject.nodes_requirements['fna_positive'] = random.choice([True, False])
            extra_cost = u.gaussian(c.pricelist["fna"][0], c.pricelist["fna"][1])
            extra_delay = u.gaussian(c.delay["fna"][0], c.delay["fna"][1])
            print('extra cost for fna: ', round(extra_cost, 2))
            print('extra delay for fna: ', int(extra_delay))
            subject.total_cost += round(extra_cost, 2) 
            subject.total_delay += int(extra_delay) 
            return        
        
def exam_for_metastasis(subject):
    for attr_name, attr_value in subject.metastasis_requirements.items():
        if attr_name == 'separate_tumor_nodules' and attr_value is None:
            subject.metastasis_requirements['separate_tumor_nodules'] = random.choice([True, False])
            extra_cost = u.gaussian(c.pricelist["scintigraphy"][0], c.pricelist["scintigraphy"][1])
            extra_delay = u.gaussian(c.delay["scintigraphy"][0], c.delay["scintigraphy"][1])
            print('extra cost for scintigraphy: ', round(extra_cost, 2))
            print('extra delay for scintigraphy: ', int(extra_delay))
            subject.total_cost += extra_cost 
            subject.total_delay += int(extra_delay) 
            return
        
        if attr_name == 'distant_metastasis' and attr_value is None:
            subject.metastasis_requirements['distant_metastasis'] = random.choice([True, False])
            extra_cost = u.gaussian(c.pricelist["mri_brain"][0], c.pricelist["mri_brain"][1])
            extra_delay = u.gaussian(c.delay["mri_brain"][0], c.delay["mri_brain"][1])
            print('extra cost for mri_brain: ', round(extra_cost, 2))
            print('extra delay for mri_brain: ', int(extra_delay))
            subject.total_cost += round(extra_cost, 2) 
            subject.total_delay += int(extra_delay) 
            return        

def estimate(subject):

    if subject.cancer_suspected == None:
        print('Suspected for cancer None')
        if ready_to_determine(subject.suspicion_requirements) == True:
            subject.cancer_suspected = determine(suspicion_engine, SUSPICION_FACTS, subject.suspicion_requirements)
        else:
            subject.set_suspicion_requirements()
            subject.cancer_suspected = determine(suspicion_engine, SUSPICION_FACTS, subject.suspicion_requirements)
        estimate(subject)
        
    elif subject.cancer_suspected == 'False':
        print('Suspected for cancer False')
        return
    
    else:
        print('Suspected for cancer True')
        
        if subject.tumor_stage == None:
            if ready_to_determine(subject.tumor_requirements) == True:
                subject.tumor_stage = determine(tumor_engine, TUMOR_FACTS, subject.tumor_requirements)
                print('Tumor estimated as: ', subject.tumor_stage)
                print('subject.tumor_requirements: ', subject.tumor_requirements)
            else:
                exam_for_tumor(subject)
                estimate(subject)        

        if subject.nodes_stage == None:
            if ready_to_determine(subject.nodes_requirements) == True:
                subject.nodes_stage = determine(nodes_engine, NODES_FACTS, subject.nodes_requirements)
                print('Nodes estimated as: ', subject.nodes_stage)
                print('subject.nodes_requirements: ', subject.nodes_requirements)
            else:
                exam_for_nodes(subject)
                estimate(subject)

        if subject.metastasis_stage == None:
            if ready_to_determine(subject.metastasis_requirements) == True:
                subject.metastasis_stage = determine(metastasis_engine, METASTASIS_FACTS, subject.metastasis_requirements)
                print('Metastasis estimated as: ', subject.metastasis_stage)
                print('subject.metastasis_requirements: ', subject.metastasis_requirements)
            else:
                exam_for_metastasis(subject)
                estimate(subject)

        if subject.cancer_stage == None:
            if subject.tumor_stage != None and subject.nodes_stage != None and subject.metastasis_stage != None:
#               if we have reached this point and either T,N or M have value None this means that no appropriate rule was found,
#               and no further exams are available for the respective T, N, M
#               therefore we should set the None to Tx, Nx or Mx respectively
                if subject.tumor_stage != None:
                    subject.tnm_requirements['T'] = subject.tumor_stage
                else:
                    subject.tnm_requirements['T'] = 'Tx'
                if subject.nodes_stage != None:
                    subject.tnm_requirements['N'] = subject.nodes_stage
                else:
                    subject.tnm_requirements['N'] = 'Nx'
                if subject.metastasis_stage != None:
                    subject.tnm_requirements['M'] = subject.metastasis_stage
                else:
                    subject.tnm_requirements['M'] = 'Mx'
                print(subject.tnm_requirements)
                subject.cancer_stage = determine(cancer_engine, TNM_FACTS, subject.tnm_requirements)
                print('Cancer estimated as: ', subject.cancer_stage)
                result = (f'Subject: {subject.id}, '
                        f'Cancer suspected: {subject.cancer_suspected}, '
                        f'Cancer diagnosis: {subject.cancer_stage}, '
                        f'Total cost: {subject.total_cost}, '
                        f'Total delay: {subject.total_delay}\n')
                print(result)
                with open('subjects_results.txt', 'a') as f:
                    # Write the data to the file
                    f.write(result)
                return
            else:
                estimate(subject)

# %%
import json
from synthesizer import *
synth = Synthesizer()

# Loading the data:
subjects = synth.load_subjects_from_json('subjects.json')
print('Total subjects: ', len(subjects))

# for each subject runfor key, value in subject.items():
for subject in subjects:
    print('Estimating for subject: ', subject.id)
    estimate(subject)
# Out:
# Total subjects:  100
# Estimating for subject:  1
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  2
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  3
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  4
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  5
# Suspected for cancer None
# Suspected for cancer True
# {'mass': None, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for chest x_rays:  8.25
# extra delay for chest x_rays:  2
# Suspected for cancer True
# {'mass': True, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for ct_scan:  58.42
# extra delay for ct_scan:  23
# Suspected for cancer True
# {'mass': True, 'diameter': 6.65, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': True}
# extra cost for bronchoscopesis:  15.24
# extra delay for bronchoscopesis:  3
# Suspected for cancer True
# {'mass': True, 'diameter': 6.65, 'bronchoscopesis': True, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': True}
# extra cost for cytologic:  16.42
# extra delay for cytologic:  3
# Suspected for cancer True
# Tumor estimated as:  T2b
# subject.tumor_requirements:  {'mass': True, 'diameter': 6.65, 'bronchoscopesis': True, 'cytologic': True, 'nearby_organs': False, 'fna_and_pet_scan': True}
# extra cost for ct_scan:  52.41
# extra delay for ct_scan:  36
# Suspected for cancer True
# extra cost for fna:  102.9
# extra delay for fna:  15
# Suspected for cancer True
# Nodes estimated as:  N3
# subject.nodes_requirements:  {'lymph_nodes_size': 5.73, 'peribronchial_metastasis': True, 'mediastinal_metastasis': True, 'fna_positive': True}
# extra cost for scintigraphy:  249.12
# extra delay for scintigraphy:  4
# Suspected for cancer True
# extra cost for mri_brain:  133.14
# extra delay for mri_brain:  13
# Suspected for cancer True
# Metastasis estimated as:  M1a
# subject.metastasis_requirements:  {'separate_tumor_nodules': True, 'distant_metastasis': False}
# {'T': 'T2b', 'N': 'N3', 'M': 'M1a'}
# Cancer estimated as:  Stage IIIC
# Subject: 5, Cancer suspected: True, Cancer diagnosis: Stage IIIC, Total cost: 635.9016305561643, Total delay: 100
#
# Estimating for subject:  6
# Suspected for cancer None
# Suspected for cancer True
# {'mass': None, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for chest x_rays:  9.5
# extra delay for chest x_rays:  3
# Suspected for cancer True
# {'mass': True, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for ct_scan:  52.55
# extra delay for ct_scan:  11
# Suspected for cancer True
# {'mass': True, 'diameter': 8.45, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': True}
# extra cost for bronchoscopesis:  15.18
# extra delay for bronchoscopesis:  3
# Suspected for cancer True
# {'mass': True, 'diameter': 8.45, 'bronchoscopesis': False, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': True}
# extra cost for cytologic:  18.72
# extra delay for cytologic:  3
# Suspected for cancer True
# Tumor estimated as:  T3
# subject.tumor_requirements:  {'mass': True, 'diameter': 8.45, 'bronchoscopesis': False, 'cytologic': True, 'nearby_organs': False, 'fna_and_pet_scan': True}
# extra cost for ct_scan:  59.35
# extra delay for ct_scan:  10
# Suspected for cancer True
# extra cost for fna:  97.78
# extra delay for fna:  16
# Suspected for cancer True
# Nodes estimated as:  N2
# subject.nodes_requirements:  {'lymph_nodes_size': 10.53, 'peribronchial_metastasis': False, 'mediastinal_metastasis': True, 'fna_positive': False}
# extra cost for scintigraphy:  252.81
# extra delay for scintigraphy:  5
# Suspected for cancer True
# extra cost for mri_brain:  131.73
# extra delay for mri_brain:  8
# Suspected for cancer True
# Metastasis estimated as:  M2b
# subject.metastasis_requirements:  {'separate_tumor_nodules': False, 'distant_metastasis': True}
# {'T': 'T3', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 6, Cancer suspected: True, Cancer diagnosis: None, Total cost: 637.6212396325382, Total delay: 60
#
# {'T': 'T3', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 6, Cancer suspected: True, Cancer diagnosis: None, Total cost: 637.6212396325382, Total delay: 60
#
# {'T': 'T3', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 6, Cancer suspected: True, Cancer diagnosis: None, Total cost: 637.6212396325382, Total delay: 60
#
# {'T': 'T3', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 6, Cancer suspected: True, Cancer diagnosis: None, Total cost: 637.6212396325382, Total delay: 60
#
# {'T': 'T3', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 6, Cancer suspected: True, Cancer diagnosis: None, Total cost: 637.6212396325382, Total delay: 60
#
# {'T': 'T3', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 6, Cancer suspected: True, Cancer diagnosis: None, Total cost: 637.6212396325382, Total delay: 60
#
# {'T': 'T3', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 6, Cancer suspected: True, Cancer diagnosis: None, Total cost: 637.6212396325382, Total delay: 60
#
# {'T': 'T3', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 6, Cancer suspected: True, Cancer diagnosis: None, Total cost: 637.6212396325382, Total delay: 60
#
# {'T': 'T3', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 6, Cancer suspected: True, Cancer diagnosis: None, Total cost: 637.6212396325382, Total delay: 60
#
# Estimating for subject:  7
# Suspected for cancer None
# Suspected for cancer True
# {'mass': None, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for chest x_rays:  8.91
# extra delay for chest x_rays:  2
# Suspected for cancer True
# {'mass': False, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for ct_scan:  65.11
# extra delay for ct_scan:  30
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for bronchoscopesis:  19.07
# extra delay for bronchoscopesis:  2
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': False, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for cytologic:  18.22
# extra delay for cytologic:  3
# Suspected for cancer True
# Tumor estimated as:  T0
# subject.tumor_requirements:  {'mass': False, 'diameter': 0.0, 'bronchoscopesis': False, 'cytologic': False, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for ct_scan:  62.4
# extra delay for ct_scan:  32
# Suspected for cancer True
# extra cost for fna:  101.38
# extra delay for fna:  7
# Suspected for cancer True
# Nodes estimated as:  N3
# subject.nodes_requirements:  {'lymph_nodes_size': 0.5, 'peribronchial_metastasis': False, 'mediastinal_metastasis': False, 'fna_positive': True}
# extra cost for scintigraphy:  242.31
# extra delay for scintigraphy:  4
# Suspected for cancer True
# extra cost for mri_brain:  129.48
# extra delay for mri_brain:  9
# Suspected for cancer True
# Metastasis estimated as:  M1a
# subject.metastasis_requirements:  {'separate_tumor_nodules': True, 'distant_metastasis': False}
# {'T': 'T0', 'N': 'N3', 'M': 'M1a'}
# Cancer estimated as:  Stage IIIC
# Subject: 7, Cancer suspected: True, Cancer diagnosis: Stage IIIC, Total cost: 646.8820982727588, Total delay: 90
#
# Estimating for subject:  8
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  9
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  10
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  11
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  12
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  13
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  14
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  15
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  16
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  17
# Suspected for cancer None
# Suspected for cancer True
# {'mass': None, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for chest x_rays:  9.01
# extra delay for chest x_rays:  3
# Suspected for cancer True
# {'mass': True, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for ct_scan:  60.85
# extra delay for ct_scan:  30
# Suspected for cancer True
# {'mass': True, 'diameter': 10.7, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': True}
# extra cost for bronchoscopesis:  18.04
# extra delay for bronchoscopesis:  3
# Suspected for cancer True
# {'mass': True, 'diameter': 10.7, 'bronchoscopesis': True, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': True}
# extra cost for cytologic:  16.69
# extra delay for cytologic:  3
# Suspected for cancer True
# Tumor estimated as:  T3
# subject.tumor_requirements:  {'mass': True, 'diameter': 10.7, 'bronchoscopesis': True, 'cytologic': False, 'nearby_organs': False, 'fna_and_pet_scan': True}
# extra cost for ct_scan:  46.05
# extra delay for ct_scan:  24
# Suspected for cancer True
# extra cost for fna:  94.55
# extra delay for fna:  20
# Suspected for cancer True
# Nodes estimated as:  N2
# subject.nodes_requirements:  {'lymph_nodes_size': 9.53, 'peribronchial_metastasis': False, 'mediastinal_metastasis': True, 'fna_positive': False}
# extra cost for scintigraphy:  252.08
# extra delay for scintigraphy:  3
# Suspected for cancer True
# extra cost for mri_brain:  135.85
# extra delay for mri_brain:  8
# Suspected for cancer True
# Metastasis estimated as:  M2b
# subject.metastasis_requirements:  {'separate_tumor_nodules': True, 'distant_metastasis': True}
# {'T': 'T3', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 17, Cancer suspected: True, Cancer diagnosis: None, Total cost: 633.1207674787648, Total delay: 95
#
# {'T': 'T3', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 17, Cancer suspected: True, Cancer diagnosis: None, Total cost: 633.1207674787648, Total delay: 95
#
# {'T': 'T3', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 17, Cancer suspected: True, Cancer diagnosis: None, Total cost: 633.1207674787648, Total delay: 95
#
# {'T': 'T3', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 17, Cancer suspected: True, Cancer diagnosis: None, Total cost: 633.1207674787648, Total delay: 95
#
# {'T': 'T3', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 17, Cancer suspected: True, Cancer diagnosis: None, Total cost: 633.1207674787648, Total delay: 95
#
# {'T': 'T3', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 17, Cancer suspected: True, Cancer diagnosis: None, Total cost: 633.1207674787648, Total delay: 95
#
# {'T': 'T3', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 17, Cancer suspected: True, Cancer diagnosis: None, Total cost: 633.1207674787648, Total delay: 95
#
# {'T': 'T3', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 17, Cancer suspected: True, Cancer diagnosis: None, Total cost: 633.1207674787648, Total delay: 95
#
# {'T': 'T3', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 17, Cancer suspected: True, Cancer diagnosis: None, Total cost: 633.1207674787648, Total delay: 95
#
# Estimating for subject:  18
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  19
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  20
# Suspected for cancer None
# Suspected for cancer True
# {'mass': None, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for chest x_rays:  8.99
# extra delay for chest x_rays:  3
# Suspected for cancer True
# {'mass': False, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for ct_scan:  45.91
# extra delay for ct_scan:  21
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for bronchoscopesis:  18.79
# extra delay for bronchoscopesis:  3
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': True, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for cytologic:  17.38
# extra delay for cytologic:  3
# Suspected for cancer True
# Tumor estimated as:  T0
# subject.tumor_requirements:  {'mass': False, 'diameter': 0.0, 'bronchoscopesis': True, 'cytologic': True, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for ct_scan:  61.03
# extra delay for ct_scan:  38
# Suspected for cancer True
# extra cost for fna:  94.4
# extra delay for fna:  24
# Suspected for cancer True
# Nodes estimated as:  Nx
# subject.nodes_requirements:  {'lymph_nodes_size': 0.5, 'peribronchial_metastasis': False, 'mediastinal_metastasis': False, 'fna_positive': False}
# extra cost for scintigraphy:  246.26
# extra delay for scintigraphy:  3
# Suspected for cancer True
# extra cost for mri_brain:  133.54
# extra delay for mri_brain:  13
# Suspected for cancer True
# Metastasis estimated as:  M1a
# subject.metastasis_requirements:  {'separate_tumor_nodules': True, 'distant_metastasis': False}
# {'T': 'T0', 'N': 'Nx', 'M': 'M1a'}
# Cancer estimated as:  Stage Undetermined
# Subject: 20, Cancer suspected: True, Cancer diagnosis: Stage Undetermined, Total cost: 626.3047613764855, Total delay: 109
#
# Estimating for subject:  21
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  22
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  23
# Suspected for cancer None
# Suspected for cancer True
# {'mass': None, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for chest x_rays:  9.2
# extra delay for chest x_rays:  2
# Suspected for cancer True
# {'mass': False, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for ct_scan:  64.07
# extra delay for ct_scan:  24
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for bronchoscopesis:  17.57
# extra delay for bronchoscopesis:  3
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': True, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for cytologic:  17.19
# extra delay for cytologic:  3
# Suspected for cancer True
# Tumor estimated as:  Tx
# subject.tumor_requirements:  {'mass': False, 'diameter': 0.0, 'bronchoscopesis': True, 'cytologic': False, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for ct_scan:  46.86
# extra delay for ct_scan:  13
# Suspected for cancer True
# extra cost for fna:  103.84
# extra delay for fna:  13
# Suspected for cancer True
# Nodes estimated as:  N2
# subject.nodes_requirements:  {'lymph_nodes_size': 8.67, 'peribronchial_metastasis': True, 'mediastinal_metastasis': True, 'fna_positive': False}
# extra cost for scintigraphy:  257.12
# extra delay for scintigraphy:  4
# Suspected for cancer True
# extra cost for mri_brain:  132.59
# extra delay for mri_brain:  9
# Suspected for cancer True
# Metastasis estimated as:  M2b
# subject.metastasis_requirements:  {'separate_tumor_nodules': True, 'distant_metastasis': True}
# {'T': 'Tx', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  Stage Undetermined
# Subject: 23, Cancer suspected: True, Cancer diagnosis: Stage Undetermined, Total cost: 648.4383832597961, Total delay: 72
#
# Estimating for subject:  24
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  25
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  26
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  27
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  28
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  29
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  30
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  31
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  32
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  33
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  34
# Suspected for cancer None
# Suspected for cancer True
# {'mass': None, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for chest x_rays:  9.05
# extra delay for chest x_rays:  2
# Suspected for cancer True
# {'mass': True, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for ct_scan:  57.53
# extra delay for ct_scan:  11
# Suspected for cancer True
# {'mass': True, 'diameter': 13.83, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': True}
# extra cost for bronchoscopesis:  17.38
# extra delay for bronchoscopesis:  2
# Suspected for cancer True
# {'mass': True, 'diameter': 13.83, 'bronchoscopesis': False, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': True}
# extra cost for cytologic:  17.51
# extra delay for cytologic:  3
# Suspected for cancer True
# Tumor estimated as:  T3
# subject.tumor_requirements:  {'mass': True, 'diameter': 13.83, 'bronchoscopesis': False, 'cytologic': True, 'nearby_organs': False, 'fna_and_pet_scan': True}
# extra cost for ct_scan:  59.83
# extra delay for ct_scan:  43
# Suspected for cancer True
# extra cost for fna:  95.24
# extra delay for fna:  11
# Suspected for cancer True
# Nodes estimated as:  N3
# subject.nodes_requirements:  {'lymph_nodes_size': 2.53, 'peribronchial_metastasis': True, 'mediastinal_metastasis': True, 'fna_positive': True}
# extra cost for scintigraphy:  253.03
# extra delay for scintigraphy:  3
# Suspected for cancer True
# extra cost for mri_brain:  131.87
# extra delay for mri_brain:  6
# Suspected for cancer True
# Metastasis estimated as:  M2b
# subject.metastasis_requirements:  {'separate_tumor_nodules': False, 'distant_metastasis': True}
# {'T': 'T3', 'N': 'N3', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 34, Cancer suspected: True, Cancer diagnosis: None, Total cost: 641.4379854467318, Total delay: 82
#
# {'T': 'T3', 'N': 'N3', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 34, Cancer suspected: True, Cancer diagnosis: None, Total cost: 641.4379854467318, Total delay: 82
#
# {'T': 'T3', 'N': 'N3', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 34, Cancer suspected: True, Cancer diagnosis: None, Total cost: 641.4379854467318, Total delay: 82
#
# {'T': 'T3', 'N': 'N3', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 34, Cancer suspected: True, Cancer diagnosis: None, Total cost: 641.4379854467318, Total delay: 82
#
# {'T': 'T3', 'N': 'N3', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 34, Cancer suspected: True, Cancer diagnosis: None, Total cost: 641.4379854467318, Total delay: 82
#
# {'T': 'T3', 'N': 'N3', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 34, Cancer suspected: True, Cancer diagnosis: None, Total cost: 641.4379854467318, Total delay: 82
#
# {'T': 'T3', 'N': 'N3', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 34, Cancer suspected: True, Cancer diagnosis: None, Total cost: 641.4379854467318, Total delay: 82
#
# {'T': 'T3', 'N': 'N3', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 34, Cancer suspected: True, Cancer diagnosis: None, Total cost: 641.4379854467318, Total delay: 82
#
# {'T': 'T3', 'N': 'N3', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 34, Cancer suspected: True, Cancer diagnosis: None, Total cost: 641.4379854467318, Total delay: 82
#
# Estimating for subject:  35
# Suspected for cancer None
# Suspected for cancer True
# {'mass': None, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for chest x_rays:  8.67
# extra delay for chest x_rays:  3
# Suspected for cancer True
# {'mass': True, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for ct_scan:  51.43
# extra delay for ct_scan:  29
# Suspected for cancer True
# {'mass': True, 'diameter': 13.94, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': True}
# extra cost for bronchoscopesis:  15.74
# extra delay for bronchoscopesis:  3
# Suspected for cancer True
# {'mass': True, 'diameter': 13.94, 'bronchoscopesis': False, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': True}
# extra cost for cytologic:  16.1
# extra delay for cytologic:  3
# Suspected for cancer True
# Tumor estimated as:  T3
# subject.tumor_requirements:  {'mass': True, 'diameter': 13.94, 'bronchoscopesis': False, 'cytologic': True, 'nearby_organs': False, 'fna_and_pet_scan': True}
# extra cost for ct_scan:  62.17
# extra delay for ct_scan:  20
# Suspected for cancer True
# extra cost for fna:  96.62
# extra delay for fna:  23
# Suspected for cancer True
# Nodes estimated as:  N3
# subject.nodes_requirements:  {'lymph_nodes_size': 3.7, 'peribronchial_metastasis': False, 'mediastinal_metastasis': True, 'fna_positive': True}
# extra cost for scintigraphy:  245.75
# extra delay for scintigraphy:  3
# Suspected for cancer True
# extra cost for mri_brain:  127.71
# extra delay for mri_brain:  8
# Suspected for cancer True
# Metastasis estimated as:  M1a
# subject.metastasis_requirements:  {'separate_tumor_nodules': True, 'distant_metastasis': False}
# {'T': 'T3', 'N': 'N3', 'M': 'M1a'}
# Cancer estimated as:  Stage IIIC
# Subject: 35, Cancer suspected: True, Cancer diagnosis: Stage IIIC, Total cost: 624.1894803729814, Total delay: 93
#
# Estimating for subject:  36
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  37
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  38
# Suspected for cancer None
# Suspected for cancer True
# {'mass': None, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for chest x_rays:  9.25
# extra delay for chest x_rays:  2
# Suspected for cancer True
# {'mass': False, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for ct_scan:  52.55
# extra delay for ct_scan:  18
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for bronchoscopesis:  17.54
# extra delay for bronchoscopesis:  2
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': False, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for cytologic:  17.09
# extra delay for cytologic:  3
# Suspected for cancer True
# Tumor estimated as:  T0
# subject.tumor_requirements:  {'mass': False, 'diameter': 0.0, 'bronchoscopesis': False, 'cytologic': False, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for ct_scan:  58.77
# extra delay for ct_scan:  12
# Suspected for cancer True
# extra cost for fna:  92.16
# extra delay for fna:  13
# Suspected for cancer True
# Nodes estimated as:  Nx
# subject.nodes_requirements:  {'lymph_nodes_size': 0.5, 'peribronchial_metastasis': False, 'mediastinal_metastasis': False, 'fna_positive': False}
# extra cost for scintigraphy:  245.58
# extra delay for scintigraphy:  4
# Suspected for cancer True
# extra cost for mri_brain:  125.78
# extra delay for mri_brain:  10
# Suspected for cancer True
# Metastasis estimated as:  M2b
# subject.metastasis_requirements:  {'separate_tumor_nodules': True, 'distant_metastasis': True}
# {'T': 'T0', 'N': 'Nx', 'M': 'M2b'}
# Cancer estimated as:  Stage Undetermined
# Subject: 38, Cancer suspected: True, Cancer diagnosis: Stage Undetermined, Total cost: 618.7227340108118, Total delay: 65
#
# Estimating for subject:  39
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  40
# Suspected for cancer None
# Suspected for cancer True
# {'mass': None, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for chest x_rays:  8.17
# extra delay for chest x_rays:  3
# Suspected for cancer True
# {'mass': False, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for ct_scan:  74.53
# extra delay for ct_scan:  31
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for bronchoscopesis:  17.67
# extra delay for bronchoscopesis:  3
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': False, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for cytologic:  17.65
# extra delay for cytologic:  3
# Suspected for cancer True
# Tumor estimated as:  T0
# subject.tumor_requirements:  {'mass': False, 'diameter': 0.0, 'bronchoscopesis': False, 'cytologic': False, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for ct_scan:  54.34
# extra delay for ct_scan:  19
# Suspected for cancer True
# extra cost for fna:  99.76
# extra delay for fna:  15
# Suspected for cancer True
# Nodes estimated as:  N3
# subject.nodes_requirements:  {'lymph_nodes_size': 0.5, 'peribronchial_metastasis': False, 'mediastinal_metastasis': False, 'fna_positive': True}
# extra cost for scintigraphy:  250.03
# extra delay for scintigraphy:  5
# Suspected for cancer True
# extra cost for mri_brain:  139.25
# extra delay for mri_brain:  14
# Suspected for cancer True
# Metastasis estimated as:  M1a
# subject.metastasis_requirements:  {'separate_tumor_nodules': True, 'distant_metastasis': False}
# {'T': 'T0', 'N': 'N3', 'M': 'M1a'}
# Cancer estimated as:  Stage IIIC
# Subject: 40, Cancer suspected: True, Cancer diagnosis: Stage IIIC, Total cost: 661.4045031431746, Total delay: 94
#
# Estimating for subject:  41
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  42
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  43
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  44
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  45
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  46
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  47
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  48
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  49
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  50
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  51
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  52
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  53
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  54
# Suspected for cancer None
# Suspected for cancer True
# {'mass': None, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for chest x_rays:  8.97
# extra delay for chest x_rays:  3
# Suspected for cancer True
# {'mass': False, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for ct_scan:  60.54
# extra delay for ct_scan:  24
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for bronchoscopesis:  15.72
# extra delay for bronchoscopesis:  2
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': False, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for cytologic:  18.1
# extra delay for cytologic:  3
# Suspected for cancer True
# Tumor estimated as:  Tx
# subject.tumor_requirements:  {'mass': False, 'diameter': 0.0, 'bronchoscopesis': False, 'cytologic': True, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for ct_scan:  49.26
# extra delay for ct_scan:  36
# Suspected for cancer True
# extra cost for fna:  98.75
# extra delay for fna:  20
# Suspected for cancer True
# Nodes estimated as:  N2
# subject.nodes_requirements:  {'lymph_nodes_size': 8.97, 'peribronchial_metastasis': True, 'mediastinal_metastasis': True, 'fna_positive': False}
# extra cost for scintigraphy:  249.58
# extra delay for scintigraphy:  4
# Suspected for cancer True
# extra cost for mri_brain:  144.31
# extra delay for mri_brain:  14
# Suspected for cancer True
# Metastasis estimated as:  M0
# subject.metastasis_requirements:  {'separate_tumor_nodules': False, 'distant_metastasis': False}
# {'T': 'Tx', 'N': 'N2', 'M': 'M0'}
# Cancer estimated as:  Stage Undetermined
# Subject: 54, Cancer suspected: True, Cancer diagnosis: Stage Undetermined, Total cost: 645.2263421956143, Total delay: 107
#
# Estimating for subject:  55
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  56
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  57
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  58
# Suspected for cancer None
# Suspected for cancer True
# {'mass': None, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for chest x_rays:  8.28
# extra delay for chest x_rays:  2
# Suspected for cancer True
# {'mass': False, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for ct_scan:  59.58
# extra delay for ct_scan:  22
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for bronchoscopesis:  16.31
# extra delay for bronchoscopesis:  3
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': True, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for cytologic:  17.11
# extra delay for cytologic:  3
# Suspected for cancer True
# Tumor estimated as:  T0
# subject.tumor_requirements:  {'mass': False, 'diameter': 0.0, 'bronchoscopesis': True, 'cytologic': True, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for ct_scan:  64.07
# extra delay for ct_scan:  24
# Suspected for cancer True
# extra cost for fna:  104.92
# extra delay for fna:  23
# Suspected for cancer True
# Nodes estimated as:  Nx
# subject.nodes_requirements:  {'lymph_nodes_size': 0.5, 'peribronchial_metastasis': False, 'mediastinal_metastasis': False, 'fna_positive': False}
# extra cost for scintigraphy:  244.55
# extra delay for scintigraphy:  5
# Suspected for cancer True
# extra cost for mri_brain:  138.51
# extra delay for mri_brain:  7
# Suspected for cancer True
# Metastasis estimated as:  M2b
# subject.metastasis_requirements:  {'separate_tumor_nodules': False, 'distant_metastasis': True}
# {'T': 'T0', 'N': 'Nx', 'M': 'M2b'}
# Cancer estimated as:  Stage Undetermined
# Subject: 58, Cancer suspected: True, Cancer diagnosis: Stage Undetermined, Total cost: 653.325689000773, Total delay: 90
#
# Estimating for subject:  59
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  60
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  61
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  62
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  63
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  64
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  65
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  66
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  67
# Suspected for cancer None
# Suspected for cancer True
# {'mass': None, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for chest x_rays:  9.53
# extra delay for chest x_rays:  3
# Suspected for cancer True
# {'mass': True, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for ct_scan:  66.08
# extra delay for ct_scan:  18
# Suspected for cancer True
# {'mass': True, 'diameter': 4.95, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': True}
# extra cost for bronchoscopesis:  19.25
# extra delay for bronchoscopesis:  3
# Suspected for cancer True
# {'mass': True, 'diameter': 4.95, 'bronchoscopesis': False, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': True}
# extra cost for cytologic:  17.92
# extra delay for cytologic:  3
# Suspected for cancer True
# Tumor estimated as:  T2a
# subject.tumor_requirements:  {'mass': True, 'diameter': 4.95, 'bronchoscopesis': False, 'cytologic': True, 'nearby_organs': False, 'fna_and_pet_scan': True}
# extra cost for ct_scan:  66.83
# extra delay for ct_scan:  13
# Suspected for cancer True
# extra cost for fna:  99.83
# extra delay for fna:  16
# Suspected for cancer True
# Nodes estimated as:  N2
# subject.nodes_requirements:  {'lymph_nodes_size': 9.15, 'peribronchial_metastasis': True, 'mediastinal_metastasis': True, 'fna_positive': False}
# extra cost for scintigraphy:  256.83
# extra delay for scintigraphy:  4
# Suspected for cancer True
# extra cost for mri_brain:  139.24
# extra delay for mri_brain:  9
# Suspected for cancer True
# Metastasis estimated as:  M2b
# subject.metastasis_requirements:  {'separate_tumor_nodules': False, 'distant_metastasis': True}
# {'T': 'T2a', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 67, Cancer suspected: True, Cancer diagnosis: None, Total cost: 675.5062814431686, Total delay: 70
#
# {'T': 'T2a', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 67, Cancer suspected: True, Cancer diagnosis: None, Total cost: 675.5062814431686, Total delay: 70
#
# {'T': 'T2a', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 67, Cancer suspected: True, Cancer diagnosis: None, Total cost: 675.5062814431686, Total delay: 70
#
# {'T': 'T2a', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 67, Cancer suspected: True, Cancer diagnosis: None, Total cost: 675.5062814431686, Total delay: 70
#
# {'T': 'T2a', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 67, Cancer suspected: True, Cancer diagnosis: None, Total cost: 675.5062814431686, Total delay: 70
#
# {'T': 'T2a', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 67, Cancer suspected: True, Cancer diagnosis: None, Total cost: 675.5062814431686, Total delay: 70
#
# {'T': 'T2a', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 67, Cancer suspected: True, Cancer diagnosis: None, Total cost: 675.5062814431686, Total delay: 70
#
# {'T': 'T2a', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 67, Cancer suspected: True, Cancer diagnosis: None, Total cost: 675.5062814431686, Total delay: 70
#
# {'T': 'T2a', 'N': 'N2', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 67, Cancer suspected: True, Cancer diagnosis: None, Total cost: 675.5062814431686, Total delay: 70
#
# Estimating for subject:  68
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  69
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  70
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  71
# Suspected for cancer None
# Suspected for cancer True
# {'mass': None, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for chest x_rays:  9.49
# extra delay for chest x_rays:  2
# Suspected for cancer True
# {'mass': False, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for ct_scan:  62.2
# extra delay for ct_scan:  34
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for bronchoscopesis:  18.98
# extra delay for bronchoscopesis:  3
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': True, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for cytologic:  17.71
# extra delay for cytologic:  3
# Suspected for cancer True
# Tumor estimated as:  T0
# subject.tumor_requirements:  {'mass': False, 'diameter': 0.0, 'bronchoscopesis': True, 'cytologic': True, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for ct_scan:  65.94
# extra delay for ct_scan:  32
# Suspected for cancer True
# extra cost for fna:  101.23
# extra delay for fna:  22
# Suspected for cancer True
# Nodes estimated as:  N3
# subject.nodes_requirements:  {'lymph_nodes_size': 0.5, 'peribronchial_metastasis': False, 'mediastinal_metastasis': False, 'fna_positive': True}
# extra cost for scintigraphy:  257.89
# extra delay for scintigraphy:  5
# Suspected for cancer True
# extra cost for mri_brain:  125.5
# extra delay for mri_brain:  12
# Suspected for cancer True
# Metastasis estimated as:  M0
# subject.metastasis_requirements:  {'separate_tumor_nodules': False, 'distant_metastasis': False}
# {'T': 'T0', 'N': 'N3', 'M': 'M0'}
# Cancer estimated as:  Stage IIIB
# Subject: 71, Cancer suspected: True, Cancer diagnosis: Stage IIIB, Total cost: 658.9449127885248, Total delay: 114
#
# Estimating for subject:  72
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  73
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  74
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  75
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  76
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  77
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  78
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  79
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  80
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  81
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  82
# Suspected for cancer None
# Suspected for cancer True
# {'mass': None, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for chest x_rays:  9.25
# extra delay for chest x_rays:  2
# Suspected for cancer True
# {'mass': False, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for ct_scan:  66.25
# extra delay for ct_scan:  39
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for bronchoscopesis:  16.97
# extra delay for bronchoscopesis:  2
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': False, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for cytologic:  18.69
# extra delay for cytologic:  3
# Suspected for cancer True
# Tumor estimated as:  Tx
# subject.tumor_requirements:  {'mass': False, 'diameter': 0.0, 'bronchoscopesis': False, 'cytologic': True, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for ct_scan:  40.95
# extra delay for ct_scan:  12
# Suspected for cancer True
# extra cost for fna:  105.81
# extra delay for fna:  18
# Suspected for cancer True
# Nodes estimated as:  N2
# subject.nodes_requirements:  {'lymph_nodes_size': 4.06, 'peribronchial_metastasis': False, 'mediastinal_metastasis': True, 'fna_positive': False}
# extra cost for scintigraphy:  251.17
# extra delay for scintigraphy:  5
# Suspected for cancer True
# extra cost for mri_brain:  131.31
# extra delay for mri_brain:  12
# Suspected for cancer True
# Metastasis estimated as:  M0
# subject.metastasis_requirements:  {'separate_tumor_nodules': False, 'distant_metastasis': False}
# {'T': 'Tx', 'N': 'N2', 'M': 'M0'}
# Cancer estimated as:  Stage Undetermined
# Subject: 82, Cancer suspected: True, Cancer diagnosis: Stage Undetermined, Total cost: 640.3979920289362, Total delay: 94
#
# Estimating for subject:  83
# Suspected for cancer None
# Suspected for cancer True
# {'mass': None, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for chest x_rays:  9.36
# extra delay for chest x_rays:  2
# Suspected for cancer True
# {'mass': False, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for ct_scan:  56.99
# extra delay for ct_scan:  24
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for bronchoscopesis:  16.13
# extra delay for bronchoscopesis:  2
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': False, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for cytologic:  17.35
# extra delay for cytologic:  3
# Suspected for cancer True
# Tumor estimated as:  Tx
# subject.tumor_requirements:  {'mass': False, 'diameter': 0.0, 'bronchoscopesis': False, 'cytologic': True, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for ct_scan:  60.83
# extra delay for ct_scan:  31
# Suspected for cancer True
# extra cost for fna:  99.74
# extra delay for fna:  13
# Suspected for cancer True
# Nodes estimated as:  N3
# subject.nodes_requirements:  {'lymph_nodes_size': 2.89, 'peribronchial_metastasis': False, 'mediastinal_metastasis': True, 'fna_positive': True}
# extra cost for scintigraphy:  255.4
# extra delay for scintigraphy:  4
# Suspected for cancer True
# extra cost for mri_brain:  134.72
# extra delay for mri_brain:  10
# Suspected for cancer True
# Metastasis estimated as:  M2b
# subject.metastasis_requirements:  {'separate_tumor_nodules': True, 'distant_metastasis': True}
# {'T': 'Tx', 'N': 'N3', 'M': 'M2b'}
# Cancer estimated as:  Stage Undetermined
# Subject: 83, Cancer suspected: True, Cancer diagnosis: Stage Undetermined, Total cost: 650.5204070662188, Total delay: 90
#
# Estimating for subject:  84
# Suspected for cancer None
# Suspected for cancer True
# {'mass': None, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for chest x_rays:  8.3
# extra delay for chest x_rays:  3
# Suspected for cancer True
# {'mass': True, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for ct_scan:  61.68
# extra delay for ct_scan:  42
# Suspected for cancer True
# {'mass': True, 'diameter': 7.67, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': True, 'fna_and_pet_scan': True}
# extra cost for bronchoscopesis:  18.52
# extra delay for bronchoscopesis:  3
# Suspected for cancer True
# {'mass': True, 'diameter': 7.67, 'bronchoscopesis': True, 'cytologic': None, 'nearby_organs': True, 'fna_and_pet_scan': True}
# extra cost for cytologic:  18.31
# extra delay for cytologic:  3
# Suspected for cancer True
# Tumor estimated as:  T4
# subject.tumor_requirements:  {'mass': True, 'diameter': 7.67, 'bronchoscopesis': True, 'cytologic': False, 'nearby_organs': True, 'fna_and_pet_scan': True}
# extra cost for ct_scan:  62.98
# extra delay for ct_scan:  32
# Suspected for cancer True
# extra cost for fna:  98.7
# extra delay for fna:  9
# Suspected for cancer True
# Nodes estimated as:  N2
# subject.nodes_requirements:  {'lymph_nodes_size': 3.74, 'peribronchial_metastasis': True, 'mediastinal_metastasis': True, 'fna_positive': False}
# extra cost for scintigraphy:  247.31
# extra delay for scintigraphy:  4
# Suspected for cancer True
# extra cost for mri_brain:  133.51
# extra delay for mri_brain:  7
# Suspected for cancer True
# Metastasis estimated as:  M0
# subject.metastasis_requirements:  {'separate_tumor_nodules': False, 'distant_metastasis': False}
# {'T': 'T4', 'N': 'N2', 'M': 'M0'}
# Cancer estimated as:  Stage IIIA
# Subject: 84, Cancer suspected: True, Cancer diagnosis: Stage IIIA, Total cost: 649.3146149316977, Total delay: 104
#
# Estimating for subject:  85
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  86
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  87
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  88
# Suspected for cancer None
# Suspected for cancer True
# {'mass': None, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for chest x_rays:  9.09
# extra delay for chest x_rays:  2
# Suspected for cancer True
# {'mass': False, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for ct_scan:  55.74
# extra delay for ct_scan:  37
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for bronchoscopesis:  17.33
# extra delay for bronchoscopesis:  3
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': False, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for cytologic:  16.19
# extra delay for cytologic:  3
# Suspected for cancer True
# Tumor estimated as:  T0
# subject.tumor_requirements:  {'mass': False, 'diameter': 0.0, 'bronchoscopesis': False, 'cytologic': False, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for ct_scan:  64.39
# extra delay for ct_scan:  36
# Suspected for cancer True
# extra cost for fna:  101.09
# extra delay for fna:  11
# Suspected for cancer True
# Nodes estimated as:  N3
# subject.nodes_requirements:  {'lymph_nodes_size': 0.5, 'peribronchial_metastasis': False, 'mediastinal_metastasis': False, 'fna_positive': True}
# extra cost for scintigraphy:  250.02
# extra delay for scintigraphy:  6
# Suspected for cancer True
# extra cost for mri_brain:  137.01
# extra delay for mri_brain:  8
# Suspected for cancer True
# Metastasis estimated as:  M2b
# subject.metastasis_requirements:  {'separate_tumor_nodules': True, 'distant_metastasis': True}
# {'T': 'T0', 'N': 'N3', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 88, Cancer suspected: True, Cancer diagnosis: None, Total cost: 650.856978009536, Total delay: 107
#
# {'T': 'T0', 'N': 'N3', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 88, Cancer suspected: True, Cancer diagnosis: None, Total cost: 650.856978009536, Total delay: 107
#
# {'T': 'T0', 'N': 'N3', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 88, Cancer suspected: True, Cancer diagnosis: None, Total cost: 650.856978009536, Total delay: 107
#
# {'T': 'T0', 'N': 'N3', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 88, Cancer suspected: True, Cancer diagnosis: None, Total cost: 650.856978009536, Total delay: 107
#
# {'T': 'T0', 'N': 'N3', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 88, Cancer suspected: True, Cancer diagnosis: None, Total cost: 650.856978009536, Total delay: 107
#
# {'T': 'T0', 'N': 'N3', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 88, Cancer suspected: True, Cancer diagnosis: None, Total cost: 650.856978009536, Total delay: 107
#
# {'T': 'T0', 'N': 'N3', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 88, Cancer suspected: True, Cancer diagnosis: None, Total cost: 650.856978009536, Total delay: 107
#
# {'T': 'T0', 'N': 'N3', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 88, Cancer suspected: True, Cancer diagnosis: None, Total cost: 650.856978009536, Total delay: 107
#
# {'T': 'T0', 'N': 'N3', 'M': 'M2b'}
# Cancer estimated as:  None
# Subject: 88, Cancer suspected: True, Cancer diagnosis: None, Total cost: 650.856978009536, Total delay: 107
#
# Estimating for subject:  89
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  90
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  91
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  92
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  93
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  94
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  95
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  96
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  97
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  98
# Suspected for cancer None
# Suspected for cancer True
# {'mass': None, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for chest x_rays:  8.47
# extra delay for chest x_rays:  2
# Suspected for cancer True
# {'mass': False, 'diameter': None, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': None, 'fna_and_pet_scan': None}
# extra cost for ct_scan:  59.8
# extra delay for ct_scan:  42
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': None, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for bronchoscopesis:  17.02
# extra delay for bronchoscopesis:  3
# Suspected for cancer True
# {'mass': False, 'diameter': 0.0, 'bronchoscopesis': False, 'cytologic': None, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for cytologic:  17.15
# extra delay for cytologic:  3
# Suspected for cancer True
# Tumor estimated as:  T0
# subject.tumor_requirements:  {'mass': False, 'diameter': 0.0, 'bronchoscopesis': False, 'cytologic': False, 'nearby_organs': False, 'fna_and_pet_scan': False}
# extra cost for ct_scan:  51.22
# extra delay for ct_scan:  28
# Suspected for cancer True
# extra cost for fna:  99.46
# extra delay for fna:  23
# Suspected for cancer True
# Nodes estimated as:  Nx
# subject.nodes_requirements:  {'lymph_nodes_size': 0.5, 'peribronchial_metastasis': False, 'mediastinal_metastasis': False, 'fna_positive': False}
# extra cost for scintigraphy:  245.9
# extra delay for scintigraphy:  4
# Suspected for cancer True
# extra cost for mri_brain:  125.33
# extra delay for mri_brain:  8
# Suspected for cancer True
# Metastasis estimated as:  M2b
# subject.metastasis_requirements:  {'separate_tumor_nodules': True, 'distant_metastasis': True}
# {'T': 'T0', 'N': 'Nx', 'M': 'M2b'}
# Cancer estimated as:  Stage Undetermined
# Subject: 98, Cancer suspected: True, Cancer diagnosis: Stage Undetermined, Total cost: 624.3465592454199, Total delay: 114
#
# Estimating for subject:  99
# Suspected for cancer None
# Suspected for cancer False
# Estimating for subject:  100
# Suspected for cancer None
# Suspected for cancer False
